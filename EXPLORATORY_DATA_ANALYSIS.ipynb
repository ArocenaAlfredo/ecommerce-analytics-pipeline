# %%
import requests
import pandas as pd

# %%
r= requests.get('https://date.nager.at/api/v3/publicholidays/2017/BR')

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'date': '2017-01-01',
#   'localName': 'Confraternização Universal',
#   'name': "New Year's Day",
#   'countryCode': 'BR',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2017-02-27',
#   'localName': 'Carnaval',
#   'name': 'Carnival',
#   'countryCode': 'BR',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Bank', 'Optional']},
#  {'date': '2017-02-28',
#   'localName': 'Carnaval',
#   'name': 'Carnival',
#   'countryCode': 'BR',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Bank', 'Optional']},
#  {'date': '2017-04-14',
#   'localName': 'Sexta-feira Santa',
#   'name': 'Good Friday',
#   'countryCode': 'BR',
#   'fixed': False,
#   'global': True,
#   'counties': None,
#   'launchYear': None,
#   'types': ['Public']},
#  {'date': '2017-04-16',
#   'localName': 'Domingo de Páscoa',
# ...

# %%
json_data= r.json()

# %%
#convert json to dataframe
df_holydays= pd.DataFrame(json_data)

#display the DataFrame
df_holydays
# Out:
#           date                             localName  \
# 0   2017-01-01            Confraternização Universal
# 1   2017-02-27                              Carnaval
# 2   2017-02-28                              Carnaval
# 3   2017-04-14                     Sexta-feira Santa
# 4   2017-04-16                     Domingo de Páscoa
# 5   2017-04-21                     Dia de Tiradentes
# 6   2017-05-01                    Dia do Trabalhador
# 7   2017-06-15                        Corpus Christi
# 8   2017-07-09  Revolução Constitucionalista de 1932
# 9   2017-09-07                  Dia da Independência
# 10  2017-10-12               Nossa Senhora Aparecida
# 11  2017-11-02                        Dia de Finados
# 12  2017-11-15              Proclamação da República
# 13  2017-12-25                                 Natal
#
#                                     name countryCode  fixed  global counties  \
# 0                         New Year's Day          BR  False    True     None
# ...

# %%
df_holydays.describe
# Out:
# <bound method NDFrame.describe of           date                             localName  \
# 0   2017-01-01            Confraternização Universal
# 1   2017-02-27                              Carnaval
# 2   2017-02-28                              Carnaval
# 3   2017-04-14                     Sexta-feira Santa
# 4   2017-04-16                     Domingo de Páscoa
# 5   2017-04-21                     Dia de Tiradentes
# 6   2017-05-01                    Dia do Trabalhador
# 7   2017-06-15                        Corpus Christi
# 8   2017-07-09  Revolução Constitucionalista de 1932
# 9   2017-09-07                  Dia da Independência
# 10  2017-10-12               Nossa Senhora Aparecida
# 11  2017-11-02                        Dia de Finados
# 12  2017-11-15              Proclamação da República
# 13  2017-12-25                                 Natal
#
#                                     name countryCode  fixed  global counties  \
# ...

# %%
df_holydays.info
# Out:
# <bound method DataFrame.info of           date                             localName  \
# 0   2017-01-01            Confraternização Universal
# 1   2017-02-27                              Carnaval
# 2   2017-02-28                              Carnaval
# 3   2017-04-14                     Sexta-feira Santa
# 4   2017-04-16                     Domingo de Páscoa
# 5   2017-04-21                     Dia de Tiradentes
# 6   2017-05-01                    Dia do Trabalhador
# 7   2017-06-15                        Corpus Christi
# 8   2017-07-09  Revolução Constitucionalista de 1932
# 9   2017-09-07                  Dia da Independência
# 10  2017-10-12               Nossa Senhora Aparecida
# 11  2017-11-02                        Dia de Finados
# 12  2017-11-15              Proclamação da República
# 13  2017-12-25                                 Natal
#
#                                     name countryCode  fixed  global counties  \
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Conéctate a la base de datos SQLite
engine = create_engine("sqlite:///database.sqlite")

# Obtener la estructura de la tabla
df = pd.read_sql("PRAGMA table_info(olist_products)", engine)
print(df)
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine

# Conéctate a la base de datos SQLite
engine = create_engine("sqlite:///database.sqlite")

# Obtener la lista de tablas
tables_df = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", engine)
print(tables_df)
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("sqlite:///database.sqlite")

# Consultar las columnas de olist_products
columns_df = pd.read_sql("PRAGMA table_info(olist_products)", engine)

# Mostrar las columnas disponibles
print(columns_df)
# Out:
# Empty DataFrame
# Columns: [cid, name, type, notnull, dflt_value, pk]
# Index: []
